# %%
import json
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
import calendar
import requests
file = "crime_clean.csv"
crime_df = pd.read_csv(file)

crime_df.head()
# Out:
#    Index                Date/Time        Date      Time  Status  \
# 0    670  2014-03-15T13:23:00.000  2014-03-15  13:23:00  Arrest
# 1    673  2016-11-25T16:56:00.000  2016-11-25  16:56:00  Arrest
# 2    679  2013-07-28T02:23:00.000  2013-07-28  02:23:00  Arrest
# 3    681  2012-07-25T10:41:00.000  2012-07-25  10:41:00  Closed
# 4    682  2015-06-19T15:54:00.000  2015-06-19  15:54:00  Closed
#
#                        Address      crime num Crime Type Committed/Attempted  \
# 0  MCQUIGG AVE / W ROBINSON ST  2014-00109569    Assault           Committed
# 1            2500 S KIRKMAN RD  2016-00475579      Theft           Committed
# 2            2500 S KIRKMAN RD  2013-00308749      Theft           Committed
# 3           3100 E COLONIAL BV  2012-00308325      Theft           Committed
# 4            2500 S KIRKMAN RD  2015-00251741      Theft           Committed
#
#                    Area Type          Sub Crime  \
# 0           Residence/Single     Simple assault
# ...

# %%
df2 = {"zipcode":[]}
crime_df = crime_df.append(df2,ignore_index=True)

# %%
crime_df.head()
# Out:
#    Index                Date/Time        Date      Time  Status  \
# 0  670.0  2014-03-15T13:23:00.000  2014-03-15  13:23:00  Arrest
# 1  673.0  2016-11-25T16:56:00.000  2016-11-25  16:56:00  Arrest
# 2  679.0  2013-07-28T02:23:00.000  2013-07-28  02:23:00  Arrest
# 3  681.0  2012-07-25T10:41:00.000  2012-07-25  10:41:00  Closed
# 4  682.0  2015-06-19T15:54:00.000  2015-06-19  15:54:00  Closed
#
#                        Address      crime num Crime Type Committed/Attempted  \
# 0  MCQUIGG AVE / W ROBINSON ST  2014-00109569    Assault           Committed
# 1            2500 S KIRKMAN RD  2016-00475579      Theft           Committed
# 2            2500 S KIRKMAN RD  2013-00308749      Theft           Committed
# 3           3100 E COLONIAL BV  2012-00308325      Theft           Committed
# 4            2500 S KIRKMAN RD  2015-00251741      Theft           Committed
#
#                    Area Type          Sub Crime  \
# 0           Residence/Single     Simple assault
# ...

# %%
#for 
import pprint as pprint
lat = crime_df['Lattitude'][0]  
long = crime_df['Longitude'][0]
target_url = 'https://maps.googleapis.com/maps/api/geocode/json?latlng='+lat +','+long +'&key=' + 'INSERT API KEY HERE'
geo_data = requests.get(target_url).json()
    
    



# Print the json
print(geo_data)
# Out:
# {'plus_code': {'compound_code': 'GJW6+73 Orlando, FL, USA', 'global_code': '76WWGJW6+73'}, 'results': [{'address_components': [{'long_name': '701', 'short_name': '701', 'types': ['street_number']}, {'long_name': 'West Robinson Street', 'short_name': 'W Robinson St', 'types': ['route']}, {'long_name': 'Northwest Orlando', 'short_name': 'Northwest Orlando', 'types': ['neighborhood', 'political']}, {'long_name': 'Orlando', 'short_name': 'Orlando', 'types': ['locality', 'political']}, {'long_name': 'Orange County', 'short_name': 'Orange County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Florida', 'short_name': 'FL', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '32805', 'short_name': '32805', 'types': ['postal_code']}, {'long_name': '1530', 'short_name': '1530', 'types': ['postal_code_suffix']}], 'formatted_address': '701 W Robinson St, Orlando, FL 3
# ...

# %%
print(json.dumps(geo_data, indent=4))
# Out:
# {
#     "plus_code": {
#         "compound_code": "GJW6+73 Orlando, FL, USA",
#         "global_code": "76WWGJW6+73"
#     },
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "701",
#                     "short_name": "701",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "West Robinson Street",
#                     "short_name": "W Robinson St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Northwest Orlando",
#                     "short_name": "Northwest Orlando",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
# ...

# %%
apple =geo_data["results"][0]["address_components"]["postal_code"]["long_name"]
apple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-2e09b7d6988a> in <module>()
# ----> 1 apple =geo_data["results"][0]["address_components"]["postal_code"]["long_name"]
#       2 apple
#
# TypeError: list indices must be integers or slices, not str
