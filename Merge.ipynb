# %%
import pandas as pd
import csv
csv_path = './census_data.csv'
csv_path2= './finalfinaldata.csv'

# %%
crime_df = pd.read_csv(csv_path2)
census_df= pd.read_csv(csv_path)

# %%
mergedf = crime_df.merge(census_df,how = 'outer', left_on = 'zipcode', right_on = 'Zipcode')

# %%
groupedf = mergedf.groupby(['Crime Type']).count()

groupedf.head()
# Out:
#             Unnamed: 0  Index  Date/Time  Date  Time  Status  Address  \
# Crime Type
# Assault             88     88         88    88    88      88       88
# Burglary           145    145        145   145   145     145      145
# Fraud               82     82         82    82    82      82       82
# Homicide             2      2          2     2     2       2        2
# Narcotics           87     87         87    87    87      87       87
#
#             crime num  Committed/Attempted  Area Type      ...       Map  \
# Crime Type                                                 ...
# Assault            88                   88         88      ...        88
# Burglary          145                  145        145      ...       145
# Fraud              82                   82         82      ...        82
# Homicide            2                    2          2      ...         2
# Narcotics          87                   87         87      ...        87
#
# ...

# %%
mergedf.head()
# Out:
#    Unnamed: 0     Index                Date/Time       Date      Time  Status  \
# 0         862  168425.0  2013-09-09T01:30:00.000   9/9/2013   1:30:00  Arrest
# 1        1685  169248.0  2015-03-08T03:56:00.000   3/8/2015   3:56:00  Arrest
# 2         774  168337.0  2010-04-16T10:21:00.000  4/16/2010  10:21:00  Closed
# 3        1147  168710.0  2013-11-01T17:05:00.000  11/1/2013  17:05:00  Closed
# 4         210  167773.0  2014-04-23T03:34:00.000  4/23/2014   3:34:00  Arrest
#
#             Address      crime num Crime Type Committed/Attempted  \
# 0     100 W PINE ST  2013-00375675  Narcotics           Committed
# 1       1 W PINE ST  2015-00097645    Assault           Committed
# 2     500 S EOLA DR  2010-00178080    Assault           Committed
# 3  100 E CENTRAL BV  2013-00458730      Theft           Committed
# 4       1 W PINE ST  2014-00167215      Theft           Committed
#
#        ...          Map    Lattitude     Longitude zipcode  Zipcode  \
# ...

# %%
DataFrame.merge(right, how='inner', on=None, left_on=None, right_on=None, left_index=False, 
                right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
